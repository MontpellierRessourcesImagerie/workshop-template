# %% [markdown]
# | [![home](../media/navigation/home.png)](../index.html) | [![next](../media/navigation/next.png)](../lectures//chapter-2.html) |
# | :---: | :---: |
# | • | Chapter 2: The second chapter |

# %% [markdown]
# # 1. Chapter One

# %% [markdown]
# The quick brown fox jumps over the lazy dog [[1]](#lit-ref-1).

# %% [markdown]
# ## 1.1 Section One

# %% [markdown]
# <figure>
#   <figcaption>Script 1.1 &ndash; Cell Detection and Multiplex Classification Script.</figcaption>
#
# ```python
# print("Hello World!")
# ```

# %% [markdown]
# $$
# I_c = I_{\tiny0, c} \cdot e^{-A \cdot c_c}
# \tag{1-1}
# $$

# %% [markdown]
# ![Kenney-Shift](../media/inputs-icons/keyboard_shift.svg) + ![Kenney-keyboard_c](../media/inputs-icons/keyboard_c.svg)

# %% [markdown]
# # Literature

# %% [markdown]
# <a id='lit-ref-1'></a>
# 1. Haralick, R.M., Shanmugam, K., Dinstein, I., 1973. [Textural Features for Image Classification](https://doi.org/10.1109/TSMC.1973.4309314). IEEE Trans. Syst., Man, Cybern. SMC-3, 610–621.
