# %% [markdown]
# # BioCampus workshop: Title
#
# ## Proposed by Montpellier Ressources Imagerie
#
# **Trainers:**
#
# - BAECKER Volker
# - BENEDETTI Clément
#
# **Requirements:** [Requirements & installation guide](exercises/extras/install-requirements.html)

# %% [markdown]
# ## Program
#
# ### 1. Chapter One
#
# - [Lecture](lectures/chapter-01.html)
#
# - [Slides](slides)
#
# - [Ex 1: Exercise one](exercises/chapter-01/ex1.html)
# - [Ex 2: Exercise two](exercises/chapter-01/ex2.html)
# - [Ex 3: Exercise three](exercises/chapter-01/ex3.html)
#
#
# ### 2. Chapter 2
#
# ...
