# %% [markdown]
# |   | [![home](../../../media/navigation/home.png)](../../index.html) |   |
# | :---: | :---: | :---: |
# |       |   •   |       |

# %% [markdown]
# # Install requirements

# %% [markdown]
# ...
