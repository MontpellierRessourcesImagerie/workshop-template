# %% [markdown]
# | [![back](../../media/navigation/back.png)](../../exercises/chapter-01/ex2.html) | [![home](../../media/navigation/home.png)](../../index.html) |
# | :---: | :---: |
# | Ex 1.2: Exercise 1.2 | • |

# %% [markdown]
# ## 1.3 ...

# %% [markdown]
# Aim:
# - ...
