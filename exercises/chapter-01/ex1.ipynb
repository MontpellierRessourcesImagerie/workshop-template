# %% [markdown]
# | [![home](../../media/navigation/home.png)](../../index.html) | [![next](../../media/navigation/next.png)](../../exercises/chapter-01/ex2.html) |
# | :---: | :---: |
# | • | Ex 2.2: The second exercise |

# %% [markdown]
# # 1. Exercises for the first chapter

# %% [markdown]
# Description of the first exercise

# %% [markdown]
# ## 1.1 First exercise of the first chapter

# %% [markdown]
# Aims:
# 1. Learn how to...
# 1. ...

# %% [markdown]
# ### 1.1.1 First part of the first exercise

# %% [markdown]
# Instructions...

# %% [markdown]
# <center>
# <img src="../../media/chapter01/od.png" alt="image 1" width="15%" >
# <br>
# <small>
# Fig. 1.1 &ndash; Description figure 1.
# </small>
# </center>

# %% [markdown]
# ### 1.1.2 Second part of the first exercise

# %% [markdown]
# Instructions...

# %% [markdown]
# <center>
# <div style="Width:70%; margin: auto;">
# <div style="width:45%;  float:left; ">
# <img src="../../media/chapter01/od-matrix.png" alt="subfigure 1" width="35%">
# <br>
# <small>
# Fig. 1.2 &ndash; Description of figure 2.
# </small>
# </div>
# <br>
# <div style= "width:45%; float:left; ">
# <img src="../../media/chapter01/od.png" alt="subfigure 2" width="35%">
# <br>
# <small>
# Fig. 1.3 &ndash; Description of figure 3
# </small>
# </div>
# </center>

# %% [markdown]
# **Note**
#
# Note that you can create notes, tips and warnings. You need to to tag the cell with the tag note, tip or warning.
